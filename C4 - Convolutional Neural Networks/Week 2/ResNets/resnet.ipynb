# %%
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
import pydot
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
from keras.utils.vis_utils import plot_model
from resnets_utils import *
from keras.initializers import glorot_uniform
import scipy.misc
from matplotlib.pyplot import imshow
# %matplotlib inline

import keras.backend as K
K.set_image_data_format('channels_last')
K.set_learning_phase(1)
# Out:
# c:\Python\Python395\lib\site-packages\keras\backend.py:450: UserWarning: `tf.keras.backend.set_learning_phase` is deprecated and will be removed after 2020-10-11. To update it, simply pass a True/False value to the `training` argument of the `__call__` method of your layer or model.
#   warnings.warn('`tf.keras.backend.set_learning_phase` is deprecated and '

# %%
# GRADED FUNCTION: identity_block

def identity_block(X, f, filters, stage, block):
    """
    Implementation of the identity block as defined in Figure 4
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    
    Returns:
    X -- output of the identity block, tensor of shape (n_H, n_W, n_C)
    """
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value. You'll need this later to add back to the main path. 
    X_shortcut = X
    
    # First component of main path
    X = Conv2D(filters = F1, kernel_size = (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)
    
    X = Conv2D(filters = F2, kernel_size = (1, 1), strides = (1,1), padding ='same', name=conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3,name=bn_name_base+'2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(filters = F3, kernel_size = (1, 1), strides = (1,1), padding ='valid', name=conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis=3,name=bn_name_base+'2c')(X)
    
    X = Add()([X,X_shortcut])
    X = Activation('relu')(X)

    return X

# %%
tf.compat.v1.reset_default_graph()

with tf.compat.v1.Session() as test:
    np.random.seed(1)
    A_prev = tf.compat.v1.placeholder("float", [3, 4, 4, 6])
    X = np.random.randn(3, 4, 4, 6)
    A = identity_block(A_prev, f = 2, filters = [2, 4, 6], stage = 1, block = 'a')
    test.run(tf.compat.v1.global_variables_initializer())
    out = test.run([A], feed_dict={A_prev: X, K.learning_phase(): 0})
    print("out = " + str(out[0][1][1][0]))
# Out:
# WARNING:tensorflow:From c:\Python\Python395\lib\site-packages\keras\layers\normalization\batch_normalization.py:532: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# out = [0.27030745 0.         1.7505068  2.1199005  0.         1.2631985 ]

# %%
# GRADED FUNCTION: convolutional_block

def convolutional_block(X, f, filters, stage, block, s = 2):
    """
    Implementation of the convolutional block as defined in Figure 4
    
    Arguments:
    X -- input tensor of shape (m, n_H_prev, n_W_prev, n_C_prev)
    f -- integer, specifying the shape of the middle CONV's window for the main path
    filters -- python list of integers, defining the number of filters in the CONV layers of the main path
    stage -- integer, used to name the layers, depending on their position in the network
    block -- string/character, used to name the layers, depending on their position in the network
    s -- Integer, specifying the stride to be used
    
    Returns:
    X -- output of the convolutional block, tensor of shape (n_H, n_W, n_C)
    """
    
    # defining name basis
    conv_name_base = 'res' + str(stage) + block + '_branch'
    bn_name_base = 'bn' + str(stage) + block + '_branch'
    
    # Retrieve Filters
    F1, F2, F3 = filters
    
    # Save the input value
    X_shortcut = X


    ##### MAIN PATH #####
    # First component of main path 
    X = Conv2D(F1, (1, 1), strides = (s,s), padding = 'valid', name = conv_name_base + '2a', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2a')(X)
    X = Activation('relu')(X)

    X = Conv2D(F2, (f, f), strides = (1,1), padding = 'same', name = conv_name_base + '2b', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2b')(X)
    X = Activation('relu')(X)

    X = Conv2D(F3, (1, 1), strides = (1,1), padding = 'valid', name = conv_name_base + '2c', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = bn_name_base + '2c')(X)
    X = Activation('relu')(X)   

    X_shortcut = Conv2D(F3, (1, 1), strides = (s,s), padding = 'valid', name = conv_name_base + '1', kernel_initializer = glorot_uniform(seed=0))(X_shortcut)
    X_shortcut = BatchNormalization(axis = 3, name = bn_name_base + '1')(X_shortcut)

    X = Add()([X_shortcut,X])
    X = Activation('relu')(X)

    return X

# %%
tf.compat.v1.reset_default_graph()

with tf.compat.v1.Session() as test:
    np.random.seed(1)
    A_prev = tf.compat.v1.placeholder("float", [3, 4, 4, 6])
    X = np.random.randn(3, 4, 4, 6)
    A = convolutional_block(A_prev, f = 2, filters = [2, 4, 6], stage = 1, block = 'a')
    test.run(tf.compat.v1.global_variables_initializer())
    out = test.run([A], feed_dict={A_prev: X, K.learning_phase(): 0})
    print("out = " + str(out[0][1][1][0]))
# Out:
# out = [0.09018461 1.2348977  0.46822017 0.0367176  0.         0.655166  ]

# %%
# GRADED FUNCTION: ResNet50

def ResNet50(input_shape = (64, 64, 3), classes = 6):
    """
    Implementation of the popular ResNet50 the following architecture:
    CONV2D -> BATCHNORM -> RELU -> MAXPOOL -> CONVBLOCK -> IDBLOCK*2 -> CONVBLOCK -> IDBLOCK*3
    -> CONVBLOCK -> IDBLOCK*5 -> CONVBLOCK -> IDBLOCK*2 -> AVGPOOL -> TOPLAYER

    Arguments:
    input_shape -- shape of the images of the dataset
    classes -- integer, number of classes

    Returns:
    model -- a Model() instance in Keras
    """
    
    # Define the input as a tensor with shape input_shape
    X_input = Input(input_shape)

    
    # Zero-Padding
    X = ZeroPadding2D((3, 3))(X_input)
    
    # Stage 1
    X = Conv2D(64, (7, 7), strides = (2, 2), name = 'conv1', kernel_initializer = glorot_uniform(seed=0))(X)
    X = BatchNormalization(axis = 3, name = 'bn_conv1')(X)
    X = Activation('relu')(X)
    X = MaxPooling2D((3, 3), strides=(2, 2))(X)

    # Stage 2
    X = convolutional_block(X, f = 3, filters = [64, 64, 256], stage = 2, block='a', s = 1)
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='b')
    X = identity_block(X, 3, [64, 64, 256], stage=2, block='c')

    X = convolutional_block(X, f = 3, filters = [128, 128, 512], stage = 3, block='a', s = 2)
    X = identity_block(X, 3, [125, 128, 512], stage=3, block='b')
    X = identity_block(X, 3, [125, 128, 512], stage=3, block='c')
    X = identity_block(X, 3, [125, 128, 512], stage=3, block='d')


    X = convolutional_block(X, f = 3, filters = [256, 256, 1024], stage = 4, block='a', s = 2)
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='b')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='c')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='d')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='e')
    X = identity_block(X, 3, [256, 256, 1024], stage=4, block='f')

    X = convolutional_block(X, f = 3, filters = [512, 512, 2048], stage = 5, block='a', s = 2)
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='b')
    X = identity_block(X, 3, [512, 512, 2048], stage=5, block='c')

    X = AveragePooling2D(pool_size=(2,2),name='avg_pool')(X)

    X = Flatten()(X)

    X = Dense(classes,activation='softmax',name='fc'+str(classes),kernel_initializer = glorot_uniform(seed=0))(X)

    model = Model(inputs = X_input, outputs = X, name='ResNet50')

    return model

# %%
model = ResNet50(input_shape = (64, 64, 3), classes = 6)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "ResNet50"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 64, 64, 3)]  0           []
#
#  zero_padding2d_2 (ZeroPadding2  (None, 70, 70, 3)   0           ['input_3[0][0]']
#  D)
#
#  conv1 (Conv2D)                 (None, 32, 32, 64)   9472        ['zero_padding2d_2[0][0]']
#
#  bn_conv1 (BatchNormalization)  (None, 32, 32, 64)   256         ['conv1[0][0]']
#
#  activation_110 (Activation)    (None, 32, 32, 64)   0           ['bn_conv1[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 15, 15, 64)  0           ['activation_110[0][0]']
#
#  res2a_branch2a (Conv2D)        (None, 15, 15, 64)   4160        ['max_pooling2d_2[0][0]']
#
#  bn2a_branch2a (BatchNormalizat  (None, 15, 15, 64)  256         ['res2a_branch2a[0][0]']
#  ion)
#
#  activation_111 (Activation)    (None, 15, 15, 64)   0           ['bn2a_branch2a[0][0]']
#
#  res2a_branch2b (Conv2D)        (None, 15, 15, 64)   36928       ['activation_111[0][0]']
#
#  bn2a_branch2b (BatchNormalizat  (None, 15, 15, 64)  256         ['res2a_branch2b[0][0]']
#  ion)
#
#  activation_112 (Activation)    (None, 15, 15, 64)   0           ['bn2a_branch2b[0][0]']
#
#  res2a_branch2c (Conv2D)        (None, 15, 15, 256)  16640       ['activation_112[0][0]']
#
#  res2a_branch1 (Conv2D)         (None, 15, 15, 256)  16640       ['max_pooling2d_2[0][0]']
#
#  bn2a_branch2c (BatchNormalizat  (None, 15, 15, 256)  1024       ['res2a_branch2c[0][0]']
#  ion)
#
#  bn2a_branch1 (BatchNormalizati  (None, 15, 15, 256)  1024       ['res2a_branch1[0][0]']
#  on)
#
#  activation_113 (Activation)    (None, 15, 15, 256)  0           ['bn2a_branch2c[0][0]']
#
#  add_33 (Add)                   (None, 15, 15, 256)  0           ['bn2a_branch1[0][0]',
#                                                                   'activation_113[0][0]']
#
#  activation_114 (Activation)    (None, 15, 15, 256)  0           ['add_33[0][0]']
#
#  res2b_branch2a (Conv2D)        (None, 15, 15, 64)   16448       ['activation_114[0][0]']
#
#  bn2b_branch2a (BatchNormalizat  (None, 15, 15, 64)  256         ['res2b_branch2a[0][0]']
#  ion)
#
#  activation_115 (Activation)    (None, 15, 15, 64)   0           ['bn2b_branch2a[0][0]']
#
#  res2b_branch2b (Conv2D)        (None, 15, 15, 64)   4160        ['activation_115[0][0]']
#
#  bn2b_branch2b (BatchNormalizat  (None, 15, 15, 64)  256         ['res2b_branch2b[0][0]']
#  ion)
#
#  activation_116 (Activation)    (None, 15, 15, 64)   0           ['bn2b_branch2b[0][0]']
#
#  res2b_branch2c (Conv2D)        (None, 15, 15, 256)  16640       ['activation_116[0][0]']
#
#  bn2b_branch2c (BatchNormalizat  (None, 15, 15, 256)  1024       ['res2b_branch2c[0][0]']
#  ion)
#
#  add_34 (Add)                   (None, 15, 15, 256)  0           ['bn2b_branch2c[0][0]',
#                                                                   'activation_114[0][0]']
#
#  activation_117 (Activation)    (None, 15, 15, 256)  0           ['add_34[0][0]']
#
#  res2c_branch2a (Conv2D)        (None, 15, 15, 64)   16448       ['activation_117[0][0]']
#
#  bn2c_branch2a (BatchNormalizat  (None, 15, 15, 64)  256         ['res2c_branch2a[0][0]']
#  ion)
#
#  activation_118 (Activation)    (None, 15, 15, 64)   0           ['bn2c_branch2a[0][0]']
#
#  res2c_branch2b (Conv2D)        (None, 15, 15, 64)   4160        ['activation_118[0][0]']
#
#  bn2c_branch2b (BatchNormalizat  (None, 15, 15, 64)  256         ['res2c_branch2b[0][0]']
#  ion)
#
#  activation_119 (Activation)    (None, 15, 15, 64)   0           ['bn2c_branch2b[0][0]']
#
#  res2c_branch2c (Conv2D)        (None, 15, 15, 256)  16640       ['activation_119[0][0]']
#
#  bn2c_branch2c (BatchNormalizat  (None, 15, 15, 256)  1024       ['res2c_branch2c[0][0]']
#  ion)
#
#  add_35 (Add)                   (None, 15, 15, 256)  0           ['bn2c_branch2c[0][0]',
#                                                                   'activation_117[0][0]']
#
#  activation_120 (Activation)    (None, 15, 15, 256)  0           ['add_35[0][0]']
#
#  res3a_branch2a (Conv2D)        (None, 8, 8, 128)    32896       ['activation_120[0][0]']
#
#  bn3a_branch2a (BatchNormalizat  (None, 8, 8, 128)   512         ['res3a_branch2a[0][0]']
#  ion)
#
#  activation_121 (Activation)    (None, 8, 8, 128)    0           ['bn3a_branch2a[0][0]']
#
#  res3a_branch2b (Conv2D)        (None, 8, 8, 128)    147584      ['activation_121[0][0]']
#
#  bn3a_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['res3a_branch2b[0][0]']
#  ion)
#
#  activation_122 (Activation)    (None, 8, 8, 128)    0           ['bn3a_branch2b[0][0]']
#
#  res3a_branch2c (Conv2D)        (None, 8, 8, 512)    66048       ['activation_122[0][0]']
#
#  res3a_branch1 (Conv2D)         (None, 8, 8, 512)    131584      ['activation_120[0][0]']
#
#  bn3a_branch2c (BatchNormalizat  (None, 8, 8, 512)   2048        ['res3a_branch2c[0][0]']
#  ion)
#
#  bn3a_branch1 (BatchNormalizati  (None, 8, 8, 512)   2048        ['res3a_branch1[0][0]']
#  on)
#
#  activation_123 (Activation)    (None, 8, 8, 512)    0           ['bn3a_branch2c[0][0]']
#
#  add_36 (Add)                   (None, 8, 8, 512)    0           ['bn3a_branch1[0][0]',
#                                                                   'activation_123[0][0]']
#
#  activation_124 (Activation)    (None, 8, 8, 512)    0           ['add_36[0][0]']
#
#  res3b_branch2a (Conv2D)        (None, 8, 8, 125)    64125       ['activation_124[0][0]']
#
#  bn3b_branch2a (BatchNormalizat  (None, 8, 8, 125)   500         ['res3b_branch2a[0][0]']
#  ion)
#
#  activation_125 (Activation)    (None, 8, 8, 125)    0           ['bn3b_branch2a[0][0]']
#
#  res3b_branch2b (Conv2D)        (None, 8, 8, 128)    16128       ['activation_125[0][0]']
#
#  bn3b_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['res3b_branch2b[0][0]']
#  ion)
#
#  activation_126 (Activation)    (None, 8, 8, 128)    0           ['bn3b_branch2b[0][0]']
#
#  res3b_branch2c (Conv2D)        (None, 8, 8, 512)    66048       ['activation_126[0][0]']
#
#  bn3b_branch2c (BatchNormalizat  (None, 8, 8, 512)   2048        ['res3b_branch2c[0][0]']
#  ion)
#
#  add_37 (Add)                   (None, 8, 8, 512)    0           ['bn3b_branch2c[0][0]',
#                                                                   'activation_124[0][0]']
#
#  activation_127 (Activation)    (None, 8, 8, 512)    0           ['add_37[0][0]']
#
#  res3c_branch2a (Conv2D)        (None, 8, 8, 125)    64125       ['activation_127[0][0]']
#
#  bn3c_branch2a (BatchNormalizat  (None, 8, 8, 125)   500         ['res3c_branch2a[0][0]']
#  ion)
#
#  activation_128 (Activation)    (None, 8, 8, 125)    0           ['bn3c_branch2a[0][0]']
#
#  res3c_branch2b (Conv2D)        (None, 8, 8, 128)    16128       ['activation_128[0][0]']
#
#  bn3c_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['res3c_branch2b[0][0]']
#  ion)
#
#  activation_129 (Activation)    (None, 8, 8, 128)    0           ['bn3c_branch2b[0][0]']
#
#  res3c_branch2c (Conv2D)        (None, 8, 8, 512)    66048       ['activation_129[0][0]']
#
#  bn3c_branch2c (BatchNormalizat  (None, 8, 8, 512)   2048        ['res3c_branch2c[0][0]']
#  ion)
#
#  add_38 (Add)                   (None, 8, 8, 512)    0           ['bn3c_branch2c[0][0]',
#                                                                   'activation_127[0][0]']
#
#  activation_130 (Activation)    (None, 8, 8, 512)    0           ['add_38[0][0]']
#
#  res3d_branch2a (Conv2D)        (None, 8, 8, 125)    64125       ['activation_130[0][0]']
#
#  bn3d_branch2a (BatchNormalizat  (None, 8, 8, 125)   500         ['res3d_branch2a[0][0]']
#  ion)
#
#  activation_131 (Activation)    (None, 8, 8, 125)    0           ['bn3d_branch2a[0][0]']
#
#  res3d_branch2b (Conv2D)        (None, 8, 8, 128)    16128       ['activation_131[0][0]']
#
#  bn3d_branch2b (BatchNormalizat  (None, 8, 8, 128)   512         ['res3d_branch2b[0][0]']
#  ion)
#
#  activation_132 (Activation)    (None, 8, 8, 128)    0           ['bn3d_branch2b[0][0]']
#
#  res3d_branch2c (Conv2D)        (None, 8, 8, 512)    66048       ['activation_132[0][0]']
#
#  bn3d_branch2c (BatchNormalizat  (None, 8, 8, 512)   2048        ['res3d_branch2c[0][0]']
#  ion)
#
#  add_39 (Add)                   (None, 8, 8, 512)    0           ['bn3d_branch2c[0][0]',
#                                                                   'activation_130[0][0]']
#
#  activation_133 (Activation)    (None, 8, 8, 512)    0           ['add_39[0][0]']
#
#  res4a_branch2a (Conv2D)        (None, 4, 4, 256)    131328      ['activation_133[0][0]']
#
#  bn4a_branch2a (BatchNormalizat  (None, 4, 4, 256)   1024        ['res4a_branch2a[0][0]']
#  ion)
#
#  activation_134 (Activation)    (None, 4, 4, 256)    0           ['bn4a_branch2a[0][0]']
#
#  res4a_branch2b (Conv2D)        (None, 4, 4, 256)    590080      ['activation_134[0][0]']
#
#  bn4a_branch2b (BatchNormalizat  (None, 4, 4, 256)   1024        ['res4a_branch2b[0][0]']
#  ion)
#
#  activation_135 (Activation)    (None, 4, 4, 256)    0           ['bn4a_branch2b[0][0]']
#
#  res4a_branch2c (Conv2D)        (None, 4, 4, 1024)   263168      ['activation_135[0][0]']
#
#  res4a_branch1 (Conv2D)         (None, 4, 4, 1024)   525312      ['activation_133[0][0]']
#
#  bn4a_branch2c (BatchNormalizat  (None, 4, 4, 1024)  4096        ['res4a_branch2c[0][0]']
#  ion)
#
#  bn4a_branch1 (BatchNormalizati  (None, 4, 4, 1024)  4096        ['res4a_branch1[0][0]']
#  on)
#
#  activation_136 (Activation)    (None, 4, 4, 1024)   0           ['bn4a_branch2c[0][0]']
#
#  add_40 (Add)                   (None, 4, 4, 1024)   0           ['bn4a_branch1[0][0]',
#                                                                   'activation_136[0][0]']
#
#  activation_137 (Activation)    (None, 4, 4, 1024)   0           ['add_40[0][0]']
#
#  res4b_branch2a (Conv2D)        (None, 4, 4, 256)    262400      ['activation_137[0][0]']
#
#  bn4b_branch2a (BatchNormalizat  (None, 4, 4, 256)   1024        ['res4b_branch2a[0][0]']
#  ion)
#
#  activation_138 (Activation)    (None, 4, 4, 256)    0           ['bn4b_branch2a[0][0]']
#
#  res4b_branch2b (Conv2D)        (None, 4, 4, 256)    65792       ['activation_138[0][0]']
#
#  bn4b_branch2b (BatchNormalizat  (None, 4, 4, 256)   1024        ['res4b_branch2b[0][0]']
#  ion)
#
#  activation_139 (Activation)    (None, 4, 4, 256)    0           ['bn4b_branch2b[0][0]']
#
#  res4b_branch2c (Conv2D)        (None, 4, 4, 1024)   263168      ['activation_139[0][0]']
#
#  bn4b_branch2c (BatchNormalizat  (None, 4, 4, 1024)  4096        ['res4b_branch2c[0][0]']
#  ion)
#
#  add_41 (Add)                   (None, 4, 4, 1024)   0           ['bn4b_branch2c[0][0]',
#                                                                   'activation_137[0][0]']
#
#  activation_140 (Activation)    (None, 4, 4, 1024)   0           ['add_41[0][0]']
#
#  res4c_branch2a (Conv2D)        (None, 4, 4, 256)    262400      ['activation_140[0][0]']
#
#  bn4c_branch2a (BatchNormalizat  (None, 4, 4, 256)   1024        ['res4c_branch2a[0][0]']
#  ion)
#
#  activation_141 (Activation)    (None, 4, 4, 256)    0           ['bn4c_branch2a[0][0]']
#
#  res4c_branch2b (Conv2D)        (None, 4, 4, 256)    65792       ['activation_141[0][0]']
#
#  bn4c_branch2b (BatchNormalizat  (None, 4, 4, 256)   1024        ['res4c_branch2b[0][0]']
#  ion)
#
#  activation_142 (Activation)    (None, 4, 4, 256)    0           ['bn4c_branch2b[0][0]']
#
#  res4c_branch2c (Conv2D)        (None, 4, 4, 1024)   263168      ['activation_142[0][0]']
#
#  bn4c_branch2c (BatchNormalizat  (None, 4, 4, 1024)  4096        ['res4c_branch2c[0][0]']
#  ion)
#
#  add_42 (Add)                   (None, 4, 4, 1024)   0           ['bn4c_branch2c[0][0]',
#                                                                   'activation_140[0][0]']
#
#  activation_143 (Activation)    (None, 4, 4, 1024)   0           ['add_42[0][0]']
#
#  res4d_branch2a (Conv2D)        (None, 4, 4, 256)    262400      ['activation_143[0][0]']
#
#  bn4d_branch2a (BatchNormalizat  (None, 4, 4, 256)   1024        ['res4d_branch2a[0][0]']
#  ion)
#
#  activation_144 (Activation)    (None, 4, 4, 256)    0           ['bn4d_branch2a[0][0]']
#
#  res4d_branch2b (Conv2D)        (None, 4, 4, 256)    65792       ['activation_144[0][0]']
#
#  bn4d_branch2b (BatchNormalizat  (None, 4, 4, 256)   1024        ['res4d_branch2b[0][0]']
#  ion)
#
#  activation_145 (Activation)    (None, 4, 4, 256)    0           ['bn4d_branch2b[0][0]']
#
#  res4d_branch2c (Conv2D)        (None, 4, 4, 1024)   263168      ['activation_145[0][0]']
#
#  bn4d_branch2c (BatchNormalizat  (None, 4, 4, 1024)  4096        ['res4d_branch2c[0][0]']
#  ion)
#
#  add_43 (Add)                   (None, 4, 4, 1024)   0           ['bn4d_branch2c[0][0]',
#                                                                   'activation_143[0][0]']
#
#  activation_146 (Activation)    (None, 4, 4, 1024)   0           ['add_43[0][0]']
#
#  res4e_branch2a (Conv2D)        (None, 4, 4, 256)    262400      ['activation_146[0][0]']
#
#  bn4e_branch2a (BatchNormalizat  (None, 4, 4, 256)   1024        ['res4e_branch2a[0][0]']
#  ion)
#
#  activation_147 (Activation)    (None, 4, 4, 256)    0           ['bn4e_branch2a[0][0]']
#
#  res4e_branch2b (Conv2D)        (None, 4, 4, 256)    65792       ['activation_147[0][0]']
#
#  bn4e_branch2b (BatchNormalizat  (None, 4, 4, 256)   1024        ['res4e_branch2b[0][0]']
#  ion)
#
#  activation_148 (Activation)    (None, 4, 4, 256)    0           ['bn4e_branch2b[0][0]']
#
#  res4e_branch2c (Conv2D)        (None, 4, 4, 1024)   263168      ['activation_148[0][0]']
#
#  bn4e_branch2c (BatchNormalizat  (None, 4, 4, 1024)  4096        ['res4e_branch2c[0][0]']
#  ion)
#
#  add_44 (Add)                   (None, 4, 4, 1024)   0           ['bn4e_branch2c[0][0]',
#                                                                   'activation_146[0][0]']
#
#  activation_149 (Activation)    (None, 4, 4, 1024)   0           ['add_44[0][0]']
#
#  res4f_branch2a (Conv2D)        (None, 4, 4, 256)    262400      ['activation_149[0][0]']
#
#  bn4f_branch2a (BatchNormalizat  (None, 4, 4, 256)   1024        ['res4f_branch2a[0][0]']
#  ion)
#
#  activation_150 (Activation)    (None, 4, 4, 256)    0           ['bn4f_branch2a[0][0]']
#
#  res4f_branch2b (Conv2D)        (None, 4, 4, 256)    65792       ['activation_150[0][0]']
#
#  bn4f_branch2b (BatchNormalizat  (None, 4, 4, 256)   1024        ['res4f_branch2b[0][0]']
#  ion)
#
#  activation_151 (Activation)    (None, 4, 4, 256)    0           ['bn4f_branch2b[0][0]']
#
#  res4f_branch2c (Conv2D)        (None, 4, 4, 1024)   263168      ['activation_151[0][0]']
#
#  bn4f_branch2c (BatchNormalizat  (None, 4, 4, 1024)  4096        ['res4f_branch2c[0][0]']
#  ion)
#
#  add_45 (Add)                   (None, 4, 4, 1024)   0           ['bn4f_branch2c[0][0]',
#                                                                   'activation_149[0][0]']
#
#  activation_152 (Activation)    (None, 4, 4, 1024)   0           ['add_45[0][0]']
#
#  res5a_branch2a (Conv2D)        (None, 2, 2, 512)    524800      ['activation_152[0][0]']
#
#  bn5a_branch2a (BatchNormalizat  (None, 2, 2, 512)   2048        ['res5a_branch2a[0][0]']
#  ion)
#
#  activation_153 (Activation)    (None, 2, 2, 512)    0           ['bn5a_branch2a[0][0]']
#
#  res5a_branch2b (Conv2D)        (None, 2, 2, 512)    2359808     ['activation_153[0][0]']
#
#  bn5a_branch2b (BatchNormalizat  (None, 2, 2, 512)   2048        ['res5a_branch2b[0][0]']
#  ion)
#
#  activation_154 (Activation)    (None, 2, 2, 512)    0           ['bn5a_branch2b[0][0]']
#
#  res5a_branch2c (Conv2D)        (None, 2, 2, 2048)   1050624     ['activation_154[0][0]']
#
#  res5a_branch1 (Conv2D)         (None, 2, 2, 2048)   2099200     ['activation_152[0][0]']
#
#  bn5a_branch2c (BatchNormalizat  (None, 2, 2, 2048)  8192        ['res5a_branch2c[0][0]']
#  ion)
#
#  bn5a_branch1 (BatchNormalizati  (None, 2, 2, 2048)  8192        ['res5a_branch1[0][0]']
#  on)
#
#  activation_155 (Activation)    (None, 2, 2, 2048)   0           ['bn5a_branch2c[0][0]']
#
#  add_46 (Add)                   (None, 2, 2, 2048)   0           ['bn5a_branch1[0][0]',
#                                                                   'activation_155[0][0]']
#
#  activation_156 (Activation)    (None, 2, 2, 2048)   0           ['add_46[0][0]']
#
#  res5b_branch2a (Conv2D)        (None, 2, 2, 512)    1049088     ['activation_156[0][0]']
#
#  bn5b_branch2a (BatchNormalizat  (None, 2, 2, 512)   2048        ['res5b_branch2a[0][0]']
#  ion)
#
#  activation_157 (Activation)    (None, 2, 2, 512)    0           ['bn5b_branch2a[0][0]']
#
#  res5b_branch2b (Conv2D)        (None, 2, 2, 512)    262656      ['activation_157[0][0]']
#
#  bn5b_branch2b (BatchNormalizat  (None, 2, 2, 512)   2048        ['res5b_branch2b[0][0]']
#  ion)
#
#  activation_158 (Activation)    (None, 2, 2, 512)    0           ['bn5b_branch2b[0][0]']
#
#  res5b_branch2c (Conv2D)        (None, 2, 2, 2048)   1050624     ['activation_158[0][0]']
#
#  bn5b_branch2c (BatchNormalizat  (None, 2, 2, 2048)  8192        ['res5b_branch2c[0][0]']
#  ion)
#
#  add_47 (Add)                   (None, 2, 2, 2048)   0           ['bn5b_branch2c[0][0]',
#                                                                   'activation_156[0][0]']
#
#  activation_159 (Activation)    (None, 2, 2, 2048)   0           ['add_47[0][0]']
#
#  res5c_branch2a (Conv2D)        (None, 2, 2, 512)    1049088     ['activation_159[0][0]']
#
#  bn5c_branch2a (BatchNormalizat  (None, 2, 2, 512)   2048        ['res5c_branch2a[0][0]']
#  ion)
#
#  activation_160 (Activation)    (None, 2, 2, 512)    0           ['bn5c_branch2a[0][0]']
#
#  res5c_branch2b (Conv2D)        (None, 2, 2, 512)    262656      ['activation_160[0][0]']
#
#  bn5c_branch2b (BatchNormalizat  (None, 2, 2, 512)   2048        ['res5c_branch2b[0][0]']
#  ion)
#
#  activation_161 (Activation)    (None, 2, 2, 512)    0           ['bn5c_branch2b[0][0]']
#
#  res5c_branch2c (Conv2D)        (None, 2, 2, 2048)   1050624     ['activation_161[0][0]']
#
#  bn5c_branch2c (BatchNormalizat  (None, 2, 2, 2048)  8192        ['res5c_branch2c[0][0]']
#  ion)
#
#  add_48 (Add)                   (None, 2, 2, 2048)   0           ['bn5c_branch2c[0][0]',
#                                                                   'activation_159[0][0]']
#
#  activation_162 (Activation)    (None, 2, 2, 2048)   0           ['add_48[0][0]']
#
#  avg_pool (AveragePooling2D)    (None, 1, 1, 2048)   0           ['activation_162[0][0]']
#
#  flatten_2 (Flatten)            (None, 2048)         0           ['avg_pool[0][0]']
#
#  fc6 (Dense)                    (None, 6)            12294       ['flatten_2[0][0]']
#
# ==================================================================================================
# Total params: 16,319,705
# Trainable params: 16,266,603
# Non-trainable params: 53,102
# __________________________________________________________________________________________________

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_dataset()

# Normalize image vectors
X_train = X_train_orig/255.
X_test = X_test_orig/255.

# Convert training and test labels to one hot matrices
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %%
model.fit(X_train, Y_train, epochs = 2, batch_size = 32)
# Out:
# Epoch 1/2
# 34/34 [==============================] - 14s 88ms/step - loss: 1.9236 - accuracy: 0.3824
# Epoch 2/2
# 34/34 [==============================] - 3s 88ms/step - loss: 0.7432 - accuracy: 0.7296

# %%
preds = model.evaluate(X_test, Y_test)
print ("Loss = " + str(preds[0]))
print ("Test Accuracy = " + str(preds[1]))
# Out:
# 4/4 [==============================] - 2s 33ms/step - loss: 5.7484 - accuracy: 0.1667
# Loss = 5.748387813568115
# Test Accuracy = 0.1666666716337204
